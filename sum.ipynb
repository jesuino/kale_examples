# %% [markdown]
# ## Kale Marshall Test
#
# In this very simple example we should observe the following:
# * Kale should use the pipeline parameters when a run is started by the user in KFP
# * Kale must also marshall a variable in step `sum` and restore it for step `print`

# %%
a = 10

# %%
b = 20

# %% [markdown]
# This should produce an artifact with the `sum_result` variable

# %%
sum_result = a + b

# %% [markdown]
# In this step Kale should recover the variable `sum_result` from the `sum` step (which should be saved as a artifact) and then use it for the print command

# %%
print("sum is ",  sum_result)
# Out:
# sum is  30
